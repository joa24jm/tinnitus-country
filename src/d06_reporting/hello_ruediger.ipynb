# %% [markdown]
# # Sample Jupyter Notebook file for analysis
#
# - Goal 1
# - Goal 2
# - Goal 3
#
# `variable_one`, `variable_two`
#
# ![image.png](attachment:image.png)

# %%
# imports
import pandas as pd

# %%
# read in the dataframe
df = pd.read_csv('../../data/02_intermediate/merged_users_with_survey_data.csv',
                low_memory=False)

# %%
# print first five rows of dataframe
df.head()
# Out:
#    Unnamed: 0   id  user_id  question1  question2  question3  question4  \
# 0           0   92      NaN        0.0        0.0   0.170818   0.666667
# 1           1   93      NaN        0.0        0.0   0.170818   0.666667
# 2           2   94      NaN        0.0        0.0   0.170818   0.666667
# 3           3   95      NaN        0.0        0.0   0.170818   0.666667
# 4           4  395      NaN        0.0        0.0   0.170818   0.666667
#
#    question5  question6  question7  ...   83   84   85 bl_answer_from country  \
# 0       0.25   0.241993   0.343416  ...  NaN  NaN  NaN            NaN     NaN
# 1       0.25   0.241993   0.343416  ...  NaN  NaN  NaN            NaN     NaN
# 2       0.25   0.241993   0.343416  ...  NaN  NaN  NaN            NaN     NaN
# 3       0.25   0.241993   0.343416  ...  NaN  NaN  NaN            NaN     NaN
# 4       0.25   0.241993   0.343416  ...  NaN  NaN  NaN            NaN     NaN
#
#   Continent_Name Country_Name  \
# ...

# %% [markdown]
# ### Codebook for data description is in `..\..\data\00_sources\codebook_johannes.xlsx`

# %%
# get infos about missing values and column names
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98074 entries, 0 to 98073
# Data columns (total 70 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Unnamed: 0                                                                    98074 non-null  int64
#  1   id                                                                            98074 non-null  int64
#  2   user_id                                                                       96981 non-null  float64
#  3   question1                                                                     96460 non-null  float64
#  4   question2                                                                     96355 non-null  float64
#  5   question3                                                                     92646 non-null  float64
# ...
