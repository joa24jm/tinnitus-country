# %% [markdown]
#  # Can we observe different worst symptoms between countries?

# %%
# add src to path so the noteboook can import utilities.py
import sys
sys.path.append('C:\\Users\\joa24jm\\Documents\\tinnitus-country\\src\\d00_utils')

# %%
# project location
p_loc = 'C:/Users/joa24jm/Documents/tinnitus-country/'

# %%
# imports
import pandas as pd
import utilities as u

# %%
# read in df
df = pd.read_csv(p_loc + 'data/02_intermediate/baseline.csv', index_col = 'Unnamed: 0',
                parse_dates = ['4', '9', 'created_at'],na_values = ['??.??.????', '27.02.2522']
                )
meta = pd.read_csv(p_loc + 'data/01_raw/users_metadata.csv', delimiter = ';')

# %%
# vlookup for country
df = pd.merge(meta[['user_id', 'country']], df, left_on='user_id', right_index=True, how = 'right')

# %%
# add season of answer
df['season'] = df.created_at.apply(u.get_season)

# %% [markdown]
# ##### Now we want to get the distribution of the worst symptom for the top ten countries

# %%
countries = df.country.value_counts()[:10].index.tolist()

# %%
symptoms = df['24'].value_counts()[:-1].index.tolist()

# %%
# rename col for better readabiliy
df.rename(columns={'24':'worst_symptom'}, inplace = True)

# %%
# reduce df to only these countries and symptoms
sub_df = df[df.country.isin(countries) & df['worst_symptom'].isin(symptoms)]

# %%
# crosstab for statistics
ct = pd.crosstab(sub_df['worst_symptom'], sub_df.country, normalize = 'columns')
# format ct for better readability
ct.style.format('{:,.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_c15a3_" ><thead>    <tr>        <th class="index_name level0" >country</th>        <th class="col_heading level0 col0" >AU</th>        <th class="col_heading level0 col1" >CA</th>        <th class="col_heading level0 col2" >CH</th>        <th class="col_heading level0 col3" >DE</th>        <th class="col_heading level0 col4" >ES</th>        <th class="col_heading level0 col5" >FR</th>        <th class="col_heading level0 col6" >GB</th>        <th class="col_heading level0 col7" >IT</th>        <th class="col_heading level0 col8" >NL</th>        <th class="col_heading level0 col9" >US</th>    </tr>    <tr>        <th class="index_name level0" >worst_symptom</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c15a3_level0_row0" class="row_heading level0 row0" >Because of the tinnitus I am more irritable with my family, friends and colleagues.</th>
#                         <td id="T_c15a3_row0_col0" class="data row0 col0" >8.45%</td>
#                         <td id="T_c15a3_row0_col1" class="data row0 col1" >0.00%</td>
#                         <td id="T_c15a3_row0_col2" class="data row0 col2" >2.63%</td>
#                         <td id="T_c15a3_row0_col3" class="data row0 col3" >6.49%</td>
#                         <td id="T_c15a3_row0_col4" class="data row0 col4" >9.76%</td>
#                         <td id="T_c15a3_row0_col5" class="data row0 col5" >9.38%</td>
#                         <td id="T_c15a3_row0_col6" class="data row0 col6" >2.99%</td>
#                         <td id="T_c15a3_row0_col7" class="data row0 col7" >8.97%</td>
#                         <td id="T_c15a3_row0_col8" class="data row0 col8" >5.14%</td>
#                         <td id="T_c15a3_row0_col9" class="data row0 col9" >5.96%</td>
#             </tr>
#             <tr>
#                         <th id="T_c15a3_level0_row1" class="row_heading level0 row1" >Because of the tinnitus I am more sensitive to environmental noises.</th>
#                         <td id="T_c15a3_row1_col0" class="data row1 col0" >7.04%</td>
#                         <td id="T_c15a3_row1_col1" class="data row1 col1" >11.57%</td>
#                         <td id="T_c15a3_row1_col2" class="data row1 col2" >12.28%</td>
#                         <td id="T_c15a3_row1_col3" class="data row1 col3" >9.54%</td>
#                         <td id="T_c15a3_row1_col4" class="data row1 col4" >4.88%</td>
#                         <td id="T_c15a3_row1_col5" class="data row1 col5" >9.38%</td>
#                         <td id="T_c15a3_row1_col6" class="data row1 col6" >4.48%</td>
#                         <td id="T_c15a3_row1_col7" class="data row1 col7" >8.97%</td>
#                         <td id="T_c15a3_row1_col8" class="data row1 col8" >6.86%</td>
#                         <td id="T_c15a3_row1_col9" class="data row1 col9" >8.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_c15a3_level0_row2" class="row_heading level0 row2" >Because of the tinnitus it is difficult to concentrate.</th>
#                         <td id="T_c15a3_row2_col0" class="data row2 col0" >8.45%</td>
#                         <td id="T_c15a3_row2_col1" class="data row2 col1" >11.57%</td>
#                         <td id="T_c15a3_row2_col2" class="data row2 col2" >6.14%</td>
#                         <td id="T_c15a3_row2_col3" class="data row2 col3" >12.60%</td>
#                         <td id="T_c15a3_row2_col4" class="data row2 col4" >13.41%</td>
#                         <td id="T_c15a3_row2_col5" class="data row2 col5" >3.12%</td>
#                         <td id="T_c15a3_row2_col6" class="data row2 col6" >6.97%</td>
#                         <td id="T_c15a3_row2_col7" class="data row2 col7" >14.10%</td>
#                         <td id="T_c15a3_row2_col8" class="data row2 col8" >13.71%</td>
#                         <td id="T_c15a3_row2_col9" class="data row2 col9" >15.46%</td>
#             </tr>
#             <tr>
#                         <th id="T_c15a3_level0_row3" class="row_heading level0 row3" >Because of the tinnitus it is difficult to follow a conversation, a piece of music or a film.</th>
#                         <td id="T_c15a3_row3_col0" class="data row3 col0" >12.68%</td>
#                         <td id="T_c15a3_row3_col1" class="data row3 col1" >10.74%</td>
#                         <td id="T_c15a3_row3_col2" class="data row3 col2" >11.40%</td>
#                         <td id="T_c15a3_row3_col3" class="data row3 col3" >14.05%</td>
#                         <td id="T_c15a3_row3_col4" class="data row3 col4" >3.66%</td>
#                         <td id="T_c15a3_row3_col5" class="data row3 col5" >9.38%</td>
#                         <td id="T_c15a3_row3_col6" class="data row3 col6" >14.43%</td>
#                         <td id="T_c15a3_row3_col7" class="data row3 col7" >6.41%</td>
#                         <td id="T_c15a3_row3_col8" class="data row3 col8" >9.71%</td>
#                         <td id="T_c15a3_row3_col9" class="data row3 col9" >16.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_c15a3_level0_row4" class="row_heading level0 row4" >Because of the tinnitus it is hard for me to get to sleep.</th>
#                         <td id="T_c15a3_row4_col0" class="data row4 col0" >16.90%</td>
#                         <td id="T_c15a3_row4_col1" class="data row4 col1" >9.92%</td>
#                         <td id="T_c15a3_row4_col2" class="data row4 col2" >10.53%</td>
#                         <td id="T_c15a3_row4_col3" class="data row4 col3" >10.61%</td>
#                         <td id="T_c15a3_row4_col4" class="data row4 col4" >12.20%</td>
#                         <td id="T_c15a3_row4_col5" class="data row4 col5" >14.06%</td>
#                         <td id="T_c15a3_row4_col6" class="data row4 col6" >16.42%</td>
#                         <td id="T_c15a3_row4_col7" class="data row4 col7" >11.54%</td>
#                         <td id="T_c15a3_row4_col8" class="data row4 col8" >8.57%</td>
#                         <td id="T_c15a3_row4_col9" class="data row4 col9" >13.78%</td>
#             </tr>
#             <tr>
#                         <th id="T_c15a3_level0_row5" class="row_heading level0 row5" >I am feeling depressed because of the tinnitus.</th>
#                         <td id="T_c15a3_row5_col0" class="data row5 col0" >19.72%</td>
#                         <td id="T_c15a3_row5_col1" class="data row5 col1" >8.26%</td>
#                         <td id="T_c15a3_row5_col2" class="data row5 col2" >10.53%</td>
#                         <td id="T_c15a3_row5_col3" class="data row5 col3" >7.79%</td>
#                         <td id="T_c15a3_row5_col4" class="data row5 col4" >13.41%</td>
#                         <td id="T_c15a3_row5_col5" class="data row5 col5" >18.75%</td>
#                         <td id="T_c15a3_row5_col6" class="data row5 col6" >18.41%</td>
#                         <td id="T_c15a3_row5_col7" class="data row5 col7" >12.82%</td>
#                         <td id="T_c15a3_row5_col8" class="data row5 col8" >14.29%</td>
#                         <td id="T_c15a3_row5_col9" class="data row5 col9" >9.68%</td>
#             </tr>
#             <tr>
#                         <th id="T_c15a3_level0_row6" class="row_heading level0 row6" >I don't have any of these symptoms.</th>
#                         <td id="T_c15a3_row6_col0" class="data row6 col0" >9.86%</td>
#                         <td id="T_c15a3_row6_col1" class="data row6 col1" >12.40%</td>
#                         <td id="T_c15a3_row6_col2" class="data row6 col2" >20.18%</td>
#                         <td id="T_c15a3_row6_col3" class="data row6 col3" >10.46%</td>
#                         <td id="T_c15a3_row6_col4" class="data row6 col4" >7.32%</td>

# %%
# reformat ct in a scientific way
# ct = u.format_ct(ct)
ct
# Out:
# country                                                   AU        CA  \
# worst_symptom
# Because of the tinnitus I am more irritable wit...  0.084507  0.000000
# Because of the tinnitus I am more sensitive to ...  0.070423  0.115702
# Because of the tinnitus it is difficult to conc...  0.084507  0.115702
# Because of the tinnitus it is difficult to foll...  0.126761  0.107438
# Because of the tinnitus it is hard for me to ge...  0.169014  0.099174
# I am feeling depressed because of the tinnitus.     0.197183  0.082645
# I don't have any of these symptoms.                 0.098592  0.123967
# I find it harder to relax because of the tinnitus.  0.140845  0.256198
# I have strong worries because of the tinnitus.      0.028169  0.099174
#
# country                                                   CH        DE  \
# worst_symptom
# Because of the tinnitus I am more irritable wit...  0.026316  0.064885
# Because of the tinnitus I am more sensitive to ...  0.122807  0.095420
# Because of the tinnitus it is difficult to conc...  0.061404  0.125954
# Because of the tinnitus it is difficult to foll...  0.114035  0.140458
# Because of the tinnitus it is hard for me to ge...  0.105263  0.106107
# I am feeling depressed because of the tinnitus.     0.105263  0.077863
# I don't have any of these symptoms.                 0.201754  0.104580
# I find it harder to relax because of the tinnitus.  0.192982  0.174809
# I have strong worries because of the tinnitus.      0.070175  0.109924
#
# country                                                   ES        FR  \
# worst_symptom
# Because of the tinnitus I am more irritable wit...  0.097561  0.093750
# Because of the tinnitus I am more sensitive to ...  0.048780  0.093750
# Because of the tinnitus it is difficult to conc...  0.134146  0.031250
# Because of the tinnitus it is difficult to foll...  0.036585  0.093750
# Because of the tinnitus it is hard for me to ge...  0.121951  0.140625
# I am feeling depressed because of the tinnitus.     0.134146  0.187500
# I don't have any of these symptoms.                 0.073171  0.062500
# I find it harder to relax because of the tinnitus.  0.182927  0.171875
# I have strong worries because of the tinnitus.      0.170732  0.125000
#
# country                                                   GB        IT  \
# worst_symptom
# Because of the tinnitus I am more irritable wit...  0.029851  0.089744
# Because of the tinnitus I am more sensitive to ...  0.044776  0.089744
# Because of the tinnitus it is difficult to conc...  0.069652  0.141026
# Because of the tinnitus it is difficult to foll...  0.144279  0.064103
# Because of the tinnitus it is hard for me to ge...  0.164179  0.115385
# I am feeling depressed because of the tinnitus.     0.184080  0.128205
# I don't have any of these symptoms.                 0.049751  0.115385
# I find it harder to relax because of the tinnitus.  0.218905  0.128205
# I have strong worries because of the tinnitus.      0.094527  0.128205
#
# country                                                   NL        US
# worst_symptom
# Because of the tinnitus I am more irritable wit...  0.051429  0.059590
# Because of the tinnitus I am more sensitive to ...  0.068571  0.080074
# Because of the tinnitus it is difficult to conc...  0.137143  0.154562
# Because of the tinnitus it is difficult to foll...  0.097143  0.160149
# Because of the tinnitus it is hard for me to ge...  0.085714  0.137803
# I am feeling depressed because of the tinnitus.     0.142857  0.096834
# I don't have any of these symptoms.                 0.062857  0.081937
# I find it harder to relax because of the tinnitus.  0.217143  0.141527
# I have strong worries because of the tinnitus.      0.137143  0.087523

# %%
# export crosstab to excel-csv
ct.to_csv(p_loc + 'results/01_tables/ct_worst_symptom_country_unformatted.csv')

# %% [markdown]
# ### Further split up this crosstab using season

# %%
# crosstab for statistics
ct = pd.crosstab([sub_df['worst_symptom'],sub_df['season']], sub_df.country, normalize = 'columns')
# reindex in a logical order
ct = ct.reindex(['spring', 'summer', 'autumn', 'winter'], level = 'season')
# format ct for better readability
ct.style.format('{:,.2%}')
# ct = u.format_ct(ct)
# Out:
# <style  type="text/css" >
# </style><table id="T_fb5e4_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >country</th>        <th class="col_heading level0 col0" >AU</th>        <th class="col_heading level0 col1" >CA</th>        <th class="col_heading level0 col2" >CH</th>        <th class="col_heading level0 col3" >DE</th>        <th class="col_heading level0 col4" >ES</th>        <th class="col_heading level0 col5" >FR</th>        <th class="col_heading level0 col6" >GB</th>        <th class="col_heading level0 col7" >IT</th>        <th class="col_heading level0 col8" >NL</th>        <th class="col_heading level0 col9" >US</th>    </tr>    <tr>        <th class="index_name level0" >worst_symptom</th>        <th class="index_name level1" >season</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb5e4_level0_row0" class="row_heading level0 row0" rowspan="4">Because of the tinnitus I am more irritable with my family, friends and colleagues.</th>
#                         <th id="T_fb5e4_level1_row0" class="row_heading level1 row0" >spring</th>
#                         <td id="T_fb5e4_row0_col0" class="data row0 col0" >1.41%</td>
#                         <td id="T_fb5e4_row0_col1" class="data row0 col1" >0.00%</td>
#                         <td id="T_fb5e4_row0_col2" class="data row0 col2" >0.00%</td>
#                         <td id="T_fb5e4_row0_col3" class="data row0 col3" >1.91%</td>
#                         <td id="T_fb5e4_row0_col4" class="data row0 col4" >4.88%</td>
#                         <td id="T_fb5e4_row0_col5" class="data row0 col5" >1.56%</td>
#                         <td id="T_fb5e4_row0_col6" class="data row0 col6" >0.50%</td>
#                         <td id="T_fb5e4_row0_col7" class="data row0 col7" >5.13%</td>
#                         <td id="T_fb5e4_row0_col8" class="data row0 col8" >1.14%</td>
#                         <td id="T_fb5e4_row0_col9" class="data row0 col9" >0.93%</td>
#             </tr>
#             <tr>
#                                 <th id="T_fb5e4_level1_row1" class="row_heading level1 row1" >summer</th>
#                         <td id="T_fb5e4_row1_col0" class="data row1 col0" >2.82%</td>
#                         <td id="T_fb5e4_row1_col1" class="data row1 col1" >0.00%</td>
#                         <td id="T_fb5e4_row1_col2" class="data row1 col2" >0.00%</td>
#                         <td id="T_fb5e4_row1_col3" class="data row1 col3" >1.37%</td>
#                         <td id="T_fb5e4_row1_col4" class="data row1 col4" >0.00%</td>
#                         <td id="T_fb5e4_row1_col5" class="data row1 col5" >3.12%</td>
#                         <td id="T_fb5e4_row1_col6" class="data row1 col6" >1.00%</td>
#                         <td id="T_fb5e4_row1_col7" class="data row1 col7" >1.28%</td>
#                         <td id="T_fb5e4_row1_col8" class="data row1 col8" >1.14%</td>
#                         <td id="T_fb5e4_row1_col9" class="data row1 col9" >1.86%</td>
#             </tr>
#             <tr>
#                                 <th id="T_fb5e4_level1_row2" class="row_heading level1 row2" >autumn</th>
#                         <td id="T_fb5e4_row2_col0" class="data row2 col0" >4.23%</td>
#                         <td id="T_fb5e4_row2_col1" class="data row2 col1" >0.00%</td>
#                         <td id="T_fb5e4_row2_col2" class="data row2 col2" >1.75%</td>
#                         <td id="T_fb5e4_row2_col3" class="data row2 col3" >1.68%</td>
#                         <td id="T_fb5e4_row2_col4" class="data row2 col4" >4.88%</td>
#                         <td id="T_fb5e4_row2_col5" class="data row2 col5" >1.56%</td>
#                         <td id="T_fb5e4_row2_col6" class="data row2 col6" >0.50%</td>
#                         <td id="T_fb5e4_row2_col7" class="data row2 col7" >1.28%</td>
#                         <td id="T_fb5e4_row2_col8" class="data row2 col8" >2.29%</td>
#                         <td id="T_fb5e4_row2_col9" class="data row2 col9" >2.23%</td>
#             </tr>
#             <tr>
#                                 <th id="T_fb5e4_level1_row3" class="row_heading level1 row3" >winter</th>
#                         <td id="T_fb5e4_row3_col0" class="data row3 col0" >0.00%</td>
#                         <td id="T_fb5e4_row3_col1" class="data row3 col1" >0.00%</td>
#                         <td id="T_fb5e4_row3_col2" class="data row3 col2" >0.88%</td>
#                         <td id="T_fb5e4_row3_col3" class="data row3 col3" >1.53%</td>
#                         <td id="T_fb5e4_row3_col4" class="data row3 col4" >0.00%</td>
#                         <td id="T_fb5e4_row3_col5" class="data row3 col5" >3.12%</td>
#                         <td id="T_fb5e4_row3_col6" class="data row3 col6" >1.00%</td>
#                         <td id="T_fb5e4_row3_col7" class="data row3 col7" >1.28%</td>
#                         <td id="T_fb5e4_row3_col8" class="data row3 col8" >0.57%</td>
#                         <td id="T_fb5e4_row3_col9" class="data row3 col9" >0.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_fb5e4_level0_row4" class="row_heading level0 row4" rowspan="4">Because of the tinnitus I am more sensitive to environmental noises.</th>
#                         <th id="T_fb5e4_level1_row4" class="row_heading level1 row4" >spring</th>
#                         <td id="T_fb5e4_row4_col0" class="data row4 col0" >1.41%</td>
#                         <td id="T_fb5e4_row4_col1" class="data row4 col1" >2.48%</td>
#                         <td id="T_fb5e4_row4_col2" class="data row4 col2" >4.39%</td>
#                         <td id="T_fb5e4_row4_col3" class="data row4 col3" >2.67%</td>
#                         <td id="T_fb5e4_row4_col4" class="data row4 col4" >0.00%</td>
#                         <td id="T_fb5e4_row4_col5" class="data row4 col5" >1.56%</td>
#                         <td id="T_fb5e4_row4_col6" class="data row4 col6" >1.99%</td>
#                         <td id="T_fb5e4_row4_col7" class="data row4 col7" >2.56%</td>
#                         <td id="T_fb5e4_row4_col8" class="data row4 col8" >1.14%</td>
#                         <td id="T_fb5e4_row4_col9" class="data row4 col9" >1.49%</td>
#             </tr>
#             <tr>
#                                 <th id="T_fb5e4_level1_row5" class="row_heading level1 row5" >summer</th>
#                         <td id="T_fb5e4_row5_col0" class="data row5 col0" >2.82%</td>
#                         <td id="T_fb5e4_row5_col1" class="data row5 col1" >3.31%</td>
#                         <td id="T_fb5e4_row5_col2" class="data row5 col2" >0.88%</td>
#                         <td id="T_fb5e4_row5_col3" class="data row5 col3" >1.83%</td>
#                         <td id="T_fb5e4_row5_col4" class="data row5 col4" >1.22%</td>
#                         <td id="T_fb5e4_row5_col5" class="data row5 col5" >6.25%</td>
#                         <td id="T_fb5e4_row5_col6" class="data row5 col6" >1.00%</td>
#                         <td id="T_fb5e4_row5_col7" class="data row5 col7" >1.28%</td>
#                         <td id="T_fb5e4_row5_col8" class="data row5 col8" >1.71%</td>
#                         <td id="T_fb5e4_row5_col9" class="data row5 col9" >2.23%</td>
#             </tr>
#             <tr>
#                                 <th id="T_fb5e4_level1_row6" class="row_heading level1 row6" >autumn</th>
#                         <td id="T_fb5e4_row6_col0" class="data row6 col0" >1.41%</td>
#                         <td id="T_fb5e4_row6_col1" class="data row6 col1" >4.13%</td>
#                         <td id="T_fb5e4_row6_col2" class="data row6 col2" >4.39%</td>
#                         <td id="T_fb5e4_row6_col3" class="data row6 col3" >2.90%</td>
#                         <td id="T_fb5e4

# %%
# export crosstab to excel-csv
ct.to_csv(p_loc + 'results/01_tables/ct_worst_symptom_season_country_unformatted.csv')

# %%
# helper cell to get the number of users per country
ct = pd.crosstab([sub_df['worst_symptom'],sub_df['season']], sub_df.country, normalize = False)
for i,s in zip(ct.columns, ct.sum()):
    print(f'{i} (n={s})')
# Out:
# AU (n=71)
# CA (n=121)
# CH (n=114)
# DE (n=1310)
# ES (n=82)
# FR (n=64)
# GB (n=201)
# IT (n=78)
# NL (n=175)
# US (n=537)
